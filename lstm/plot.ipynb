# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
N = 2
path = f"data/ngram_{N}/"

test = pd.read_csv(path + 'test_result.txt', sep='    ')
# Out:
# /var/folders/gq/gwfhyzf925b2_vdp2wp5svf00000gr/T/ipykernel_3545/3401029557.py:4: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   test = pd.read_csv(path + 'test_result.txt', sep='    ')

# %%
test['origin'] = test.index
#reset index
test = test.reset_index(drop=True)

# %%
# barplot
melted = pd.melt(test, value_vars=[ 'precision', 'recall', 'f1-score'], id_vars=['origin'])
melted
# Out:
#                                    origin   variable  value
# 0        Asian,GreaterEastAsian,EastAsian  precision   0.85
# 1         Asian,GreaterEastAsian,Japanese  precision   0.91
# 2                Asian,IndianSubContinent  precision   0.82
# 3                 GreaterAfrican,Africans  precision   0.47
# 4                   GreaterAfrican,Muslim  precision   0.65
# 5                 GreaterEuropean,British  precision   0.76
# 6            GreaterEuropean,EastEuropean  precision   0.77
# 7                  GreaterEuropean,Jewish  precision   0.46
# 8     GreaterEuropean,WestEuropean,French  precision   0.68
# 9   GreaterEuropean,WestEuropean,Germanic  precision   0.47
# 10  GreaterEuropean,WestEuropean,Hispanic  precision   0.71
# 11   GreaterEuropean,WestEuropean,Italian  precision   0.74
# 12    GreaterEuropean,WestEuropean,Nordic  precision   0.74
# 13       Asian,GreaterEastAsian,EastAsian     recall   0.77
# 14        Asian,GreaterEastAsian,Japanese     recall   0.88
# 15               Asian,IndianSubContinent     recall   0.73
# 16                GreaterAfrican,Africans     recall   0.35
# 17                  GreaterAfrican,Muslim     recall   0.66
# 18                GreaterEuropean,British     recall   0.88
# 19           GreaterEuropean,EastEuropean     recall   0.74
# 20                 GreaterEuropean,Jewish     recall   0.42
# 21    GreaterEuropean,WestEuropean,French     recall   0.62
# 22  GreaterEuropean,WestEuropean,Germanic     recall   0.41
# 23  GreaterEuropean,WestEuropean,Hispanic     recall   0.67
# 24   GreaterEuropean,WestEuropean,Italian     recall   0.74
# 25    GreaterEuropean,WestEuropean,Nordic     recall   0.64
# 26       Asian,GreaterEastAsian,EastAsian   f1-score   0.81
# 27        Asian,GreaterEastAsian,Japanese   f1-score   0.89
# 28               Asian,IndianSubContinent   f1-score   0.77
# 29                GreaterAfrican,Africans   f1-score   0.40
# 30                  GreaterAfrican,Muslim   f1-score   0.66
# 31                GreaterEuropean,British   f1-score   0.81
# 32           GreaterEuropean,EastEuropean   f1-score   0.76
# 33                 GreaterEuropean,Jewish   f1-score   0.44
# 34    GreaterEuropean,WestEuropean,French   f1-score   0.65
# 35  GreaterEuropean,WestEuropean,Germanic   f1-score   0.44
# 36  GreaterEuropean,WestEuropean,Hispanic   f1-score   0.69
# 37   GreaterEuropean,WestEuropean,Italian   f1-score   0.74
# 38    GreaterEuropean,WestEuropean,Nordic   f1-score   0.69

# %%
sns.set_theme (style="whitegrid", font_scale=1.5,palette='Dark2')

fig, ax = plt.subplots(figsize=(10, 6), )
sns.barplot(x='origin', y='value', hue='variable', data=melted, ax=ax)
ax.legend(loc='upper left', bbox_to_anchor=(1, 1))
ax.set_title(f"ngram = {N}")

#rotate xtick
x = plt.setp(ax.get_xticklabels(), rotation=45, horizontalalignment='right')
